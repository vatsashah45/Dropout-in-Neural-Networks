# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
score = json.load(open('OverfittedModel', 'r'))
plt.figure(1)
plt.plot(score['acc'])
plt.plot(score['val_acc'])
plt.title('No dropout model accuracy - RCV1')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.ylim([0.0,1.0])
plt.savefig('OverfittedModel.png', bbox_inches='tight')
plt.show()

# %%
score = json.load(open('DropoutModel', 'r'))
plt.figure(1)
plt.plot(score['acc'])
plt.plot(score['val_acc'])
plt.title('Dropout model accuracy - RCV1')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.ylim([0.0,1.0])
plt.savefig('DropoutModel.png', bbox_inches='tight')
plt.show()
