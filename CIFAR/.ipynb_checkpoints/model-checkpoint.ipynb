# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from keras import Input
from keras.models import Sequential
from keras.layers import  Dense, Dropout, Conv2D, Flatten, GlobalMaxPooling2D, MaxPooling2D, Input, BatchNormalization, AveragePooling2D
import json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import tensorflow as tf
#       2 from tensorflow import keras
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# ## Loading datasets

# %%
x_trainC = np.load('x_trainC.npy')
y_trainC = np.load('y_trainC.npy')
x_testC = np.load('x_testC.npy')
y_testC = np.load('y_testC.npy')

# %%
feature_shape = x_trainC[0].shape

# %%
y_trainC.shape
# Out:
# (50000, 10)

# %% [markdown]
# ## Dropout model

# %%
model = Sequential()


model.add(Conv2D(32, (3, 3), activation='relu', padding='same',input_shape=feature_shape))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))
 
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
 
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.4))

 
model.add(Dense(10, activation='softmax'))


model.summary()
opt = tf.keras.optimizers.Adam()
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['acc'])

score = model.fit(x_trainC, y_trainC, epochs=30, batch_size=20 ,validation_data=(x_testC, y_testC))
json.dump(score.history, open("WorkingModel", 'w'))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 2,397,226
# Trainable params: 2,396,330
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/30
# 2500/2500 [==============================] - 22s 8ms/step - loss: 1.6195 - acc: 0.4365 - val_loss: 1.1531 - val_acc: 0.5830
# Epoch 2/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 1.1722 - acc: 0.5932 - val_loss: 0.9978 - val_acc: 0.6551
# Epoch 3/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.9969 - acc: 0.6551 - val_loss: 0.8058 - val_acc: 0.7274
# Epoch 4/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.8802 - acc: 0.6971 - val_loss: 0.7348 - val_acc: 0.7454
# Epoch 5/30
# 2500/2500 [==============================] - 20s 8ms/step - loss: 0.7949 - acc: 0.7279 - val_loss: 0.7241 - val_acc: 0.7558
# Epoch 6/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.7246 - acc: 0.7506 - val_loss: 0.7026 - val_acc: 0.7553
# Epoch 7/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.6665 - acc: 0.7702 - val_loss: 0.6040 - val_acc: 0.7953
# Epoch 8/30
# 2500/2500 [==============================] - 20s 8ms/step - loss: 0.6286 - acc: 0.7825 - val_loss: 0.5832 - val_acc: 0.8020
# Epoch 9/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.5850 - acc: 0.7982 - val_loss: 0.5815 - val_acc: 0.8069
# Epoch 10/30
# 2500/2500 [==============================] - 20s 8ms/step - loss: 0.5514 - acc: 0.8105 - val_loss: 0.5195 - val_acc: 0.8242
# Epoch 11/30
# 2500/2500 [==============================] - 20s 8ms/step - loss: 0.5324 - acc: 0.8177 - val_loss: 0.5284 - val_acc: 0.8215
# Epoch 12/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.5058 - acc: 0.8246 - val_loss: 0.5271 - val_acc: 0.8277
# Epoch 13/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.4808 - acc: 0.8340 - val_loss: 0.5587 - val_acc: 0.8054
# Epoch 14/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.4590 - acc: 0.8382 - val_loss: 0.5110 - val_acc: 0.8276
# Epoch 15/30
# 2500/2500 [==============================] - 20s 8ms/step - loss: 0.4522 - acc: 0.8437 - val_loss: 0.4724 - val_acc: 0.8450
# Epoch 16/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.4361 - acc: 0.8496 - val_loss: 0.5240 - val_acc: 0.8255
# Epoch 17/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.4208 - acc: 0.8536 - val_loss: 0.5135 - val_acc: 0.8266
# Epoch 18/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.4024 - acc: 0.8608 - val_loss: 0.5081 - val_acc: 0.8410
# Epoch 19/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.3977 - acc: 0.8617 - val_loss: 0.4977 - val_acc: 0.8422
# Epoch 20/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.3811 - acc: 0.8671 - val_loss: 0.4718 - val_acc: 0.8503
# Epoch 21/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.3776 - acc: 0.8708 - val_loss: 0.4567 - val_acc: 0.8478
# Epoch 22/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.3613 - acc: 0.8742 - val_loss: 0.5207 - val_acc: 0.8443
# Epoch 23/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.3547 - acc: 0.8777 - val_loss: 0.4650 - val_acc: 0.8502
# Epoch 24/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.3416 - acc: 0.8813 - val_loss: 0.4721 - val_acc: 0.8479
# Epoch 25/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.3379 - acc: 0.8840 - val_loss: 0.4723 - val_acc: 0.8529
# Epoch 26/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.3314 - acc: 0.8849 - val_loss: 0.4765 - val_acc: 0.8543
# Epoch 27/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.3199 - acc: 0.8878 - val_loss: 0.4820 - val_acc: 0.8485
# Epoch 28/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.3205 - acc: 0.8879 - val_loss: 0.4830 - val_acc: 0.8485
# Epoch 29/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.3116 - acc: 0.8933 - val_loss: 0.4477 - val_acc: 0.8587
# Epoch 30/30
# 2500/2500 [==============================] - 20s 8ms/step - loss: 0.3068 - acc: 0.8946 - val_loss: 0.4901 - val_acc: 0.8552

# %% [markdown]
# ## Overfitted model

# %%
model = Sequential()


model.add(Conv2D(32, (3, 3), activation='relu', padding='same',input_shape=feature_shape))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
 
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
 
model.add(Flatten())
 
model.add(Dense(1024, activation='relu'))

 
model.add(Dense(10, activation='softmax'))


model.summary()
opt = tf.keras.optimizers.Adam()
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['acc'])

score = model.fit(x_trainC, y_trainC, epochs=30, batch_size=20 ,validation_data=(x_testC, y_testC))
json.dump(score.history, open("OverfittedModel", 'w'))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 2,397,226
# Trainable params: 2,396,330
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/30
# 2500/2500 [==============================] - 22s 8ms/step - loss: 1.1876 - acc: 0.5891 - val_loss: 1.0354 - val_acc: 0.6486
# Epoch 2/30
# 2500/2500 [==============================] - 20s 8ms/step - loss: 0.7605 - acc: 0.7358 - val_loss: 0.9705 - val_acc: 0.6707
# Epoch 3/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.5955 - acc: 0.7942 - val_loss: 0.7563 - val_acc: 0.7484
# Epoch 4/30
# 2500/2500 [==============================] - 19s 7ms/step - loss: 0.4683 - acc: 0.8380 - val_loss: 0.7262 - val_acc: 0.7671
# Epoch 5/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.3675 - acc: 0.8748 - val_loss: 0.6408 - val_acc: 0.7996
# Epoch 6/30
# 2500/2500 [==============================] - 19s 7ms/step - loss: 0.2818 - acc: 0.9011 - val_loss: 0.6841 - val_acc: 0.7971
# Epoch 7/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.2166 - acc: 0.9241 - val_loss: 0.7632 - val_acc: 0.7960
# Epoch 8/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.1726 - acc: 0.9412 - val_loss: 0.7714 - val_acc: 0.8060
# Epoch 9/30
# 2500/2500 [==============================] - 19s 7ms/step - loss: 0.1411 - acc: 0.9507 - val_loss: 0.8277 - val_acc: 0.8002
# Epoch 10/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.1178 - acc: 0.9601 - val_loss: 0.8662 - val_acc: 0.7988
# Epoch 11/30
# 2500/2500 [==============================] - 19s 7ms/step - loss: 0.1122 - acc: 0.9619 - val_loss: 1.0073 - val_acc: 0.7945
# Epoch 12/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0952 - acc: 0.9687 - val_loss: 1.1063 - val_acc: 0.7926
# Epoch 13/30
# 2500/2500 [==============================] - 19s 8ms/step - loss: 0.0903 - acc: 0.9702 - val_loss: 0.9809 - val_acc: 0.8063
# Epoch 14/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0796 - acc: 0.9737 - val_loss: 1.0755 - val_acc: 0.8062
# Epoch 15/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0724 - acc: 0.9763 - val_loss: 1.0831 - val_acc: 0.8038
# Epoch 16/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0664 - acc: 0.9776 - val_loss: 1.0892 - val_acc: 0.8113
# Epoch 17/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0683 - acc: 0.9777 - val_loss: 1.0223 - val_acc: 0.8101
# Epoch 18/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0612 - acc: 0.9800 - val_loss: 1.1142 - val_acc: 0.8036
# Epoch 19/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0558 - acc: 0.9821 - val_loss: 1.1637 - val_acc: 0.8096
# Epoch 20/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0545 - acc: 0.9826 - val_loss: 1.1154 - val_acc: 0.8004
# Epoch 21/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0512 - acc: 0.9840 - val_loss: 1.1074 - val_acc: 0.8053
# Epoch 22/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0490 - acc: 0.9845 - val_loss: 1.1745 - val_acc: 0.8101
# Epoch 23/30
# 2500/2500 [==============================] - 19s 7ms/step - loss: 0.0422 - acc: 0.9863 - val_loss: 1.2248 - val_acc: 0.8102
# Epoch 24/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0502 - acc: 0.9841 - val_loss: 1.3115 - val_acc: 0.8085
# Epoch 25/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0448 - acc: 0.9858 - val_loss: 1.1538 - val_acc: 0.8104
# Epoch 26/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0435 - acc: 0.9859 - val_loss: 1.1980 - val_acc: 0.8083
# Epoch 27/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0377 - acc: 0.9879 - val_loss: 1.1346 - val_acc: 0.8177
# Epoch 28/30
# 2500/2500 [==============================] - 18s 7ms/step - loss: 0.0423 - acc: 0.9867 - val_loss: 1.0812 - val_acc: 0.8129
# Epoch 29/30
# 2500/2500 [==============================] - 19s 7ms/step - loss: 0.0349 - acc: 0.9882 - val_loss: 1.3273 - val_acc: 0.8055
# Epoch 30/30
# 2500/2500 [==============================] - 19s 7ms/step - loss: 0.0348 - acc: 0.9890 - val_loss: 1.2100 - val_acc: 0.8041

# %%
print('GPU name: ', tf.config.experimental.list_physical_devices('GPU'))
